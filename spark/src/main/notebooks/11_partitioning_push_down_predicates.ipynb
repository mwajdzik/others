# %% [markdown]
# ## SparkSession

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName('Apache Spark test') \
    .config("spark.sql.shuffle.partitions", "50") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://172.19.30.152:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Apache Spark test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## DataFrame

# %%
df = spark.read.parquet("/Users/sg0218817/Desktop/olap/*.parquet")

# %%
df.count()

# %%
df.collect()[0]

# %%
df.rdd.getNumPartitions()

# %%
fdf = df \
    .filter('cabinCode = "Y"') \
    .groupBy('legCabinId') \
        .sum('reservationHoldings.resHoldTotal', 'reservationHoldings.resHoldGroup') \
        .withColumnRenamed('sum(reservationHoldings.resHoldTotal AS `resHoldTotal`)', 'resHoldTotal') \
        .withColumnRenamed('sum(reservationHoldings.resHoldGroup AS `resHoldGroup`)', 'resHoldGroup') \
    .cache()

# %%
fdf.explain()

# %%
fdf.count()

# %%
fdf.rdd.getNumPartitions()

# %%
fdf.show(10, False)

# %% [markdown]
# ## Partitioning and PushDown Predicates

# %%
import pyspark.sql.functions as pf
  
df.sort('departureDate') \
    .withColumn('departureDate_year', pf.year(pf.col('departureDate'))) \
    .withColumn('departureDate_month', pf.month(pf.col('departureDate'))) \
    .withColumn('departureDate_day', pf.dayofmonth(pf.col('departureDate'))) \
    .coalesce(10) \
    .write \
        .format('parquet') \
        .mode('overwrite') \
        .partitionBy('departureDate_year', 'departureDate_month') \
        .save('plik.parquet')

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .collect()
# Out:
# [Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
# ...
#  Row(legClassId='SVO.SU.1520[2019-05-06].NUX.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 15)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  ...]

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .explain()
# Out:
# == Physical Plan ==
# *(1) Project [legClassId#719, departureDate#728]
# +- *(1) FileScan parquet [legClassId#719,departureDate#728,departureDate_year#741,departureDate_month#742] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/sg0218817/Private/IT/others/spark/notebooks/plik.parquet], PartitionCount: 13, PartitionFilters: [], PushedFilters: [], ReadSchema: struct<legClassId:string,departureDate:timestamp>

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019') \
    .collect()
# Out:
# [Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
# ...
#  Row(legClassId='SVO.SU.1520[2019-05-06].NUX.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 15)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  ...]

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019') \
    .explain()
# Out:
# == Physical Plan ==
# *(1) Project [legClassId#855, departureDate#864]
# +- *(1) FileScan parquet [legClassId#855,departureDate#864,departureDate_year#877,departureDate_month#878] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/sg0218817/Private/IT/others/spark/notebooks/plik.parquet], PartitionCount: 9, PartitionFilters: [isnotnull(departureDate_year#877), (departureDate_year#877 = 2019)], PushedFilters: [], ReadSchema: struct<legClassId:string,departureDate:timestamp>

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5') \
    .collect()
# Out:
# [Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.36[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 30)),
#  Row(legClassId='SVO.SU.2550[2019-05-06].AMS.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 10)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.522[2019-05-12].DWC.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 35)),
#  Row(legClassId='SVO.SU.2596[2019-05-06].VCE.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1234[2019-05-12].UFA.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 40)),
#  Row(legClassId='SVO.SU.1620[2019-05-06].SIP.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.B', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.M', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.U', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.P', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.K', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.H', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.L', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.X', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.T', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='NUX.SU.1523[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 15)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.E', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.N', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.R', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.G', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.Y.V', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.J', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.C', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.D', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.I', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.Z', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='MCX.SU.1057[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='ALA.SU.1943[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 25)),
#  Row(legClassId='SVO.SU.1164[2019-05-12].ROV.J.O', departureDate=datetime.datetime(2019, 5, 12, 3, 55)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='CDG.SU.3001[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='SVO.SU.1864[2019-05-12].EVN.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 5)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1100[2019-05-06].KRR.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='IST.SU.2135[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 15)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='SVO.SU.1230[2019-05-06].UFA.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='AER.SU.6568[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 20)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='KGD.SU.6324[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 30)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='MRV.SU.1315[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 4, 25)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.D', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.I', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.Z', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='ROV.SU.6194[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 35)),
#  Row(legClassId='SVO.SU.1208[2019-05-06].KUF.J.O', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
#  Row(legClassId='SVO.SU.12[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 11, 40)),
#  Row(legClassId='EVN.SU.1869[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 4, 45)),
# ...
#  Row(legClassId='SVO.SU.1520[2019-05-06].NUX.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 15)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='KUF.SU.1207[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='TJM.SU.1503[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='SVO.SU.2658[2019-05-06].CPH.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='PEE.SU.6582[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 25)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='ARH.SU.6304[2019-05-06].LED.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 20)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='OMS.SU.6472[2019-05-12].LED.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 30)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.J', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.C', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.D', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.I', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='RTW.SU.1357[2019-05-06].SVO.J.O', departureDate=datetime.datetime(2019, 5, 6, 12, 25)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.J', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.C', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.D', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.I', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='UFA.SU.1239[2019-05-12].SVO.J.O', departureDate=datetime.datetime(2019, 5, 12, 7, 40)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  Row(legClassId='MMK.SU.1321[2019-05-06].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 6, 12, 35)),
#  Row(legClassId='ALA.SU.1947[2019-05-12].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 12, 7, 50)),
#  ...]

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5') \
    .explain()
# Out:
# == Physical Plan ==
# *(1) Project [legClassId#991, departureDate#1000]
# +- *(1) FileScan parquet [legClassId#991,departureDate#1000,departureDate_year#1013,departureDate_month#1014] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/sg0218817/Private/IT/others/spark/notebooks/plik.parquet], PartitionCount: 1, PartitionFilters: [isnotnull(departureDate_year#1013), isnotnull(departureDate_month#1014), (departureDate_year#101..., PushedFilters: [], ReadSchema: struct<legClassId:string,departureDate:timestamp>

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5 and departureDate_day = 1') \
    .collect()
# Out:
# [Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='SVO.SU.1834[2019-04-30].MSQ.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 0)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='EGO.SU.1375[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 5)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.6567[2019-04-30].AER.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='LED.SU.29[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 10)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='AER.SU.6562[2019-04-30].LED.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='SVO.SU.1762[2019-04-30].OMS.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 25)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='UUS.SU.5629[2019-04-30].KHV.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='GOJ.SU.1341[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='STR.SU.2339[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='AER.SU.1119[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 30)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='PEE.SU.1205[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 35)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.B', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.M', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.U', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.P', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.K', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.H', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.L', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.X', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.T', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.E', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.N', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.R', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.G', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.Y.V', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.J', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.C', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.D', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.I', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.Z', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1646[2019-04-30].NJC.J.O', departureDate=datetime.datetime(2019, 5, 1, 0, 50)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.1128[2019-04-30].AER.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 10)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='SVO.SU.34[2019-04-30].LED.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 15)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='MUC.SU.2595[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='RTW.SU.1359[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 20)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='VCE.SU.2423[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 25)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='CEK.SU.1427[2019-04-30].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 30)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='LED.SU.6595[2019-04-30].KZN.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1960[2019-04-30].KZO.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.P', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.K', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.H', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.L', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.X', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.T', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.E', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.N', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.R', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.G', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.Y.V', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.J', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.C', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.D', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.I', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.Z', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='SVO.SU.1112[2019-04-30].KRR.J.O', departureDate=datetime.datetime(2019, 5, 1, 1, 35)),
#  Row(legClassId='ICN.SU.5435[2019-04-30].VVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 1, 40)),
#  Row(legClassId='ICN.SU.5435[2019-04-30].VVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 1, 40)),
#  Row(legClassId='ICN.SU.5435[2019-04-30].VVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 1, 40)),
#  Row(legClassId='ICN.SU.5435[2019-04-30].VVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 1, 40)),
# ...
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.P', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='SVO.SU.1562[2019-05-01].IKT.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 5)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='GOT.SU.2181[2019-05-01].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 10)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.P', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1512[2019-05-01].SGC.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 35)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.P', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1234[2019-05-01].UFA.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 40)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.P', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='SVO.SU.1288[2019-05-01].ULV.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='LCA.SU.2071[2019-05-01].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 50)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.P', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.J', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.C', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.D', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.I', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='MCX.SU.1057[2019-05-01].SVO.J.O', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='SVO.SU.1436[2019-05-01].SVX.Y.Y', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='SVO.SU.1436[2019-05-01].SVX.Y.B', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='SVO.SU.1436[2019-05-01].SVX.Y.M', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  Row(legClassId='SVO.SU.1436[2019-05-01].SVX.Y.U', departureDate=datetime.datetime(2019, 5, 1, 3, 55)),
#  ...]

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5 and departureDate_day = 15') \
    .explain()
# Out:
# == Physical Plan ==
# *(1) Project [legClassId#1127, departureDate#1136]
# +- *(1) Filter (isnotnull(departureDate_day#1148) && (departureDate_day#1148 = 15))
#    +- *(1) FileScan parquet [legClassId#1127,departureDate#1136,departureDate_day#1148,departureDate_year#1149,departureDate_month#1150] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/sg0218817/Private/IT/others/spark/notebooks/plik.parquet], PartitionCount: 1, PartitionFilters: [isnotnull(departureDate_year#1149), isnotnull(departureDate_month#1150), (departureDate_year#114..., PushedFilters: [IsNotNull(departureDate_day), EqualTo(departureDate_day,15)], ReadSchema: struct<legClassId:string,departureDate:timestamp,departureDate_day:int>

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5 and departureDate_day = 15 and origin = "BCN"') \
    .collect()
# Out:
# [Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.J', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.C', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.D', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.I', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.2639[2019-05-15].SVO.J.O', departureDate=datetime.datetime(2019, 5, 15, 13, 50)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.Y', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.B', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.M', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.U', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.K', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.H', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.L', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.X', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.Q', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.T', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.E', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.N', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.R', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.G', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.Y.V', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.J', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.C', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.D', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.I', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.Z', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.6702[2019-05-15].LED.J.O', departureDate=datetime.datetime(2019, 5, 15, 13, 55)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.Y', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.B', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.M', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.U', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.K', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.H', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.L', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.X', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.Q', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.T', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.E', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.N', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.R', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.G', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.Y.V', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.J', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.C', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.D', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.I', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.Z', departureDate=datetime.datetime(2019, 5, 15, 18, 50)),
#  Row(legClassId='BCN.SU.2515[2019-05-15].SVO.J.O', departureDate=datetime.datetime(2019, 5, 15, 18, 50))]

# %%
spark.read.load("plik.parquet") \
    .select('legClassId', 'departureDate') \
    .filter('departureDate_year = 2019 and departureDate_month = 5 and departureDate_day = 15 and origin = "BCN"') \
    .explain()
# Out:
# == Physical Plan ==
# *(1) Project [legClassId#1263, departureDate#1272]
# +- *(1) Filter (((isnotnull(departureDate_day#1284) && isnotnull(origin#1273)) && (departureDate_day#1284 = 15)) && (origin#1273 = BCN))
#    +- *(1) FileScan parquet [legClassId#1263,departureDate#1272,origin#1273,departureDate_day#1284,departureDate_year#1285,departureDate_month#1286] Batched: true, Format: Parquet, Location: InMemoryFileIndex[file:/Users/sg0218817/Private/IT/others/spark/notebooks/plik.parquet], PartitionCount: 1, PartitionFilters: [isnotnull(departureDate_year#1285), isnotnull(departureDate_month#1286), (departureDate_year#128..., PushedFilters: [IsNotNull(departureDate_day), IsNotNull(origin), EqualTo(departureDate_day,15), EqualTo(origin,B..., ReadSchema: struct<legClassId:string,departureDate:timestamp,origin:string,departureDate_day:int>
